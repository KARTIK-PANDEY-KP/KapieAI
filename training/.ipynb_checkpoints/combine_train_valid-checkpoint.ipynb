# %%
import tensorflow as tf
import tensorflow.keras.backend as K
from tensorflow.keras.layers import Conv2D, Flatten, MaxPooling2D,Dense,Dropout,BatchNormalization
from tensorflow.keras.models  import Sequential, Model, load_model
from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img, array_to_img
import pickle
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import gc
import os
import random
import math
import efficientnet.tfkeras as efn

# %%
from tensorflow.compat.v1.keras.backend import set_session
config = tf.compat.v1.ConfigProto()
config.gpu_options.allow_growth = True  # dynamically grow the memory used on the GPU
config.log_device_placement = True  # to log device placement (on which device the operation ran)
sess = tf.compat.v1.Session(config=config)
set_session(sess)  # set this TensorFlow session as the default session for Keras
# Out:
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: NVIDIA GeForce RTX 3060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'csv_file',
#  'fold',
#  'models',
#  'predict',
#  'submission',
#  'tools',
#  'train',
#  'training']

# %%
BATCH_SIZE = 10
BATCH_SIZE_FT = 40
IMG_SIZE = 512
NUM_CLASSES = 7
ROOT_PATH = ""
IMAGE_PATH = "train"
FOLD_PATH = "fold"
INITAL_EPOCHS = 5
EPOCHS = 20
SPLIT = 0.2
FOLD = 0

# %%
train = pd.read_csv(ROOT_PATH + "csv_file" + "/"  + "train_one_hot.csv")
train['label'] = train['label'].astype('str')
print("Length of train = {}".format(len(train)))
# Out:
# Length of train = 32090

# %%
_datagen_train = ImageDataGenerator(rescale = 1./255.,
            fill_mode = "nearest",
            featurewise_center=False,
            featurewise_std_normalization=False,
            rotation_range=20,
            width_shift_range=0.2,
            height_shift_range=0.2,
            brightness_range=[0.5,1.2],
            zoom_range=[0.5,1.3],
            horizontal_flip=True,
            )

# %%
columns=["class_1.0", "class_2.0", "class_3.0", "class_4.0", "class_5.0", "class_6.0", "class_7.0"]
train_generator = _datagen_train.flow_from_dataframe(
            dataframe=train,
            directory=IMAGE_PATH,
            validation_split=0.2,
            x_col="image_id",
            y_col=columns,
            has_ext=False,
            batch_size=BATCH_SIZE,
            seed=42,
            shuffle=True,
            class_mode="raw",
            target_size=(IMG_SIZE, IMG_SIZE))
# Out:
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\KARTIK\anaconda3\lib\logging\__init__.py", line 1081, in emit
#     msg = self.format(record)
#   File "C:\Users\KARTIK\anaconda3\lib\logging\__init__.py", line 925, in format
#     return fmt.format(record)
#   File "C:\Users\KARTIK\anaconda3\lib\logging\__init__.py", line 664, in format
#     record.message = record.getMessage()
#   File "C:\Users\KARTIK\anaconda3\lib\logging\__init__.py", line 369, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "C:\Users\KARTIK\anaconda3\lib\runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\KARTIK\anaconda3\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\KARTIK\anaconda3\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Users\KARTIK\anaconda3\lib\site-packages\traitlets\config\application.py", line 845, in launch_instance
#     app.start()
#   File "C:\Users\KARTIK\anaconda3\lib\site-packages\ipykernel\kernelapp.py", line 612, in start
#     self.io_loop.start()
#   File "C:\Users\KARTIK\anaconda3\lib\site-packages\tornado\platform\asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\KARTIK\anaconda3\lib\asyncio\base_events.py", line 570, in run_forever
#     self._run_once()
#   File "C:\Users\KARTIK\anaconda3\lib\asyncio\base_events.py", line 1859, in _run_once
#     handle._run()
#   File "C:\Users\KARTIK\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\KARTIK\anaconda3\lib\site-packages\tornado\ioloop.py", line 688, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "C:\Users\KARTIK\anaconda3\lib\site-packages\tornado\ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "C:\Users\KARTIK\anaconda3\lib\site-packages\tornado\gen.py", line 814, in inner
#     self.ctx_run(self.run)
#   File "C:\Users\KARTIK\anaconda3\lib\site-packages\tornado\gen.py", line 775, in run
#     yielded = self.gen.send(value)
#   File "C:\Users\KARTIK\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 365, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "C:\Users\KARTIK\anaconda3\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "C:\Users\KARTIK\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 268, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "C:\Users\KARTIK\anaconda3\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "C:\Users\KARTIK\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 543, in execute_request
#     self.do_execute(
#   File "C:\Users\KARTIK\anaconda3\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "C:\Users\KARTIK\anaconda3\lib\site-packages\ipykernel\ipkernel.py", line 306, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Users\KARTIK\anaconda3\lib\site-packages\ipykernel\zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Users\KARTIK\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2894, in run_cell
#     result = self._run_cell(
#   File "C:\Users\KARTIK\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2940, in _run_cell
#     return runner(coro)
#   File "C:\Users\KARTIK\anaconda3\lib\site-packages\IPython\core\async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\KARTIK\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3165, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\KARTIK\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3357, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "C:\Users\KARTIK\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3437, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-57-09046ed571e8>", line 2, in <module>
#     train_generator = _datagen_train.flow_from_dataframe(
#   File "C:\Users\KARTIK\anaconda3\lib\site-packages\keras\preprocessing\image.py", line 1098, in flow_from_dataframe
#     tf_logging.warning(
#   File "C:\Users\KARTIK\anaconda3\lib\site-packages\tensorflow\python\platform\tf_logging.py", line 178, in warning
#     get_logger().warning(msg, *args, **kwargs)
# Message: 'has_ext is deprecated, filenames in the dataframe have to match the exact filenames in disk.'
# Arguments: (<class 'DeprecationWarning'>,)
# Found 13439 validated image filenames.

# %%
base_model =  efn.EfficientNetB6(weights='imagenet', include_top=False, pooling='avg', input_shape=(IMG_SIZE, IMG_SIZE, 3))
x = base_model.output
_x = (Dropout(0.3))(x)
predictions = Dense(NUM_CLASSES, activation="sigmoid")(_x)
model =  Model(inputs=base_model.input, outputs=predictions)

# %%
model.load_weights(ROOT_PATH + '/' + "models/EfnB6_multi_label_model_combine_1.h5")

# %%
base_model.trainable = False
fine_tune_at = 50
for layer in base_model.layers[-fine_tune_at:]:
    layer.trainable =  True

# %%
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 512, 512, 3  0           []
#                                 )]
#
#  stem_conv (Conv2D)             (None, 256, 256, 56  1512        ['input_3[0][0]']
#                                 )
#
#  stem_bn (BatchNormalization)   (None, 256, 256, 56  224         ['stem_conv[0][0]']
#                                 )
#
#  stem_activation (Activation)   (None, 256, 256, 56  0           ['stem_bn[0][0]']
#                                 )
#
#  block1a_dwconv (DepthwiseConv2  (None, 256, 256, 56  504        ['stem_activation[0][0]']
#  D)                             )
#
#  block1a_bn (BatchNormalization  (None, 256, 256, 56  224        ['block1a_dwconv[0][0]']
#  )                              )
#
#  block1a_activation (Activation  (None, 256, 256, 56  0          ['block1a_bn[0][0]']
#  )                              )
#
#  block1a_se_squeeze (GlobalAver  (None, 56)          0           ['block1a_activation[0][0]']
#  agePooling2D)
#
#  block1a_se_reshape (Reshape)   (None, 1, 1, 56)     0           ['block1a_se_squeeze[0][0]']
#
#  block1a_se_reduce (Conv2D)     (None, 1, 1, 14)     798         ['block1a_se_reshape[0][0]']
#
#  block1a_se_expand (Conv2D)     (None, 1, 1, 56)     840         ['block1a_se_reduce[0][0]']
#
#  block1a_se_excite (Multiply)   (None, 256, 256, 56  0           ['block1a_activation[0][0]',
#                                 )                                 'block1a_se_expand[0][0]']
#
#  block1a_project_conv (Conv2D)  (None, 256, 256, 32  1792        ['block1a_se_excite[0][0]']
#                                 )
#
#  block1a_project_bn (BatchNorma  (None, 256, 256, 32  128        ['block1a_project_conv[0][0]']
#  lization)                      )
#
#  block1b_dwconv (DepthwiseConv2  (None, 256, 256, 32  288        ['block1a_project_bn[0][0]']
#  D)                             )
#
#  block1b_bn (BatchNormalization  (None, 256, 256, 32  128        ['block1b_dwconv[0][0]']
#  )                              )
#
#  block1b_activation (Activation  (None, 256, 256, 32  0          ['block1b_bn[0][0]']
#  )                              )
#
#  block1b_se_squeeze (GlobalAver  (None, 32)          0           ['block1b_activation[0][0]']
#  agePooling2D)
#
#  block1b_se_reshape (Reshape)   (None, 1, 1, 32)     0           ['block1b_se_squeeze[0][0]']
#
#  block1b_se_reduce (Conv2D)     (None, 1, 1, 8)      264         ['block1b_se_reshape[0][0]']
#
#  block1b_se_expand (Conv2D)     (None, 1, 1, 32)     288         ['block1b_se_reduce[0][0]']
#
#  block1b_se_excite (Multiply)   (None, 256, 256, 32  0           ['block1b_activation[0][0]',
#                                 )                                 'block1b_se_expand[0][0]']
#
#  block1b_project_conv (Conv2D)  (None, 256, 256, 32  1024        ['block1b_se_excite[0][0]']
#                                 )
#
#  block1b_project_bn (BatchNorma  (None, 256, 256, 32  128        ['block1b_project_conv[0][0]']
#  lization)                      )
#
#  block1b_drop (FixedDropout)    (None, 256, 256, 32  0           ['block1b_project_bn[0][0]']
#                                 )
#
#  block1b_add (Add)              (None, 256, 256, 32  0           ['block1b_drop[0][0]',
#                                 )                                 'block1a_project_bn[0][0]']
#
#  block1c_dwconv (DepthwiseConv2  (None, 256, 256, 32  288        ['block1b_add[0][0]']
#  D)                             )
#
#  block1c_bn (BatchNormalization  (None, 256, 256, 32  128        ['block1c_dwconv[0][0]']
#  )                              )
#
#  block1c_activation (Activation  (None, 256, 256, 32  0          ['block1c_bn[0][0]']
#  )                              )
#
#  block1c_se_squeeze (GlobalAver  (None, 32)          0           ['block1c_activation[0][0]']
#  agePooling2D)
#
#  block1c_se_reshape (Reshape)   (None, 1, 1, 32)     0           ['block1c_se_squeeze[0][0]']
#
#  block1c_se_reduce (Conv2D)     (None, 1, 1, 8)      264         ['block1c_se_reshape[0][0]']
#
#  block1c_se_expand (Conv2D)     (None, 1, 1, 32)     288         ['block1c_se_reduce[0][0]']
#
#  block1c_se_excite (Multiply)   (None, 256, 256, 32  0           ['block1c_activation[0][0]',
#                                 )                                 'block1c_se_expand[0][0]']
#
#  block1c_project_conv (Conv2D)  (None, 256, 256, 32  1024        ['block1c_se_excite[0][0]']
#                                 )
#
#  block1c_project_bn (BatchNorma  (None, 256, 256, 32  128        ['block1c_project_conv[0][0]']
#  lization)                      )
#
#  block1c_drop (FixedDropout)    (None, 256, 256, 32  0           ['block1c_project_bn[0][0]']
#                                 )
#
#  block1c_add (Add)              (None, 256, 256, 32  0           ['block1c_drop[0][0]',
#                                 )                                 'block1b_add[0][0]']
#
#  block2a_expand_conv (Conv2D)   (None, 256, 256, 19  6144        ['block1c_add[0][0]']
#                                 2)
#
#  block2a_expand_bn (BatchNormal  (None, 256, 256, 19  768        ['block2a_expand_conv[0][0]']
#  ization)                       2)
#
#  block2a_expand_activation (Act  (None, 256, 256, 19  0          ['block2a_expand_bn[0][0]']
#  ivation)                       2)
#
#  block2a_dwconv (DepthwiseConv2  (None, 128, 128, 19  1728       ['block2a_expand_activation[0][0]
#  D)                             2)                               ']
#
#  block2a_bn (BatchNormalization  (None, 128, 128, 19  768        ['block2a_dwconv[0][0]']
#  )                              2)
#
#  block2a_activation (Activation  (None, 128, 128, 19  0          ['block2a_bn[0][0]']
#  )                              2)
#
#  block2a_se_squeeze (GlobalAver  (None, 192)         0           ['block2a_activation[0][0]']
#  agePooling2D)
#
#  block2a_se_reshape (Reshape)   (None, 1, 1, 192)    0           ['block2a_se_squeeze[0][0]']
#
#  block2a_se_reduce (Conv2D)     (None, 1, 1, 8)      1544        ['block2a_se_reshape[0][0]']
#
#  block2a_se_expand (Conv2D)     (None, 1, 1, 192)    1728        ['block2a_se_reduce[0][0]']
#
#  block2a_se_excite (Multiply)   (None, 128, 128, 19  0           ['block2a_activation[0][0]',
#                                 2)                                'block2a_se_expand[0][0]']
#
#  block2a_project_conv (Conv2D)  (None, 128, 128, 40  7680        ['block2a_se_excite[0][0]']
#                                 )
#
#  block2a_project_bn (BatchNorma  (None, 128, 128, 40  160        ['block2a_project_conv[0][0]']
#  lization)                      )
#
#  block2b_expand_conv (Conv2D)   (None, 128, 128, 24  9600        ['block2a_project_bn[0][0]']
#                                 0)
#
#  block2b_expand_bn (BatchNormal  (None, 128, 128, 24  960        ['block2b_expand_conv[0][0]']
#  ization)                       0)
#
#  block2b_expand_activation (Act  (None, 128, 128, 24  0          ['block2b_expand_bn[0][0]']
#  ivation)                       0)
#
#  block2b_dwconv (DepthwiseConv2  (None, 128, 128, 24  2160       ['block2b_expand_activation[0][0]
#  D)                             0)                               ']
#
#  block2b_bn (BatchNormalization  (None, 128, 128, 24  960        ['block2b_dwconv[0][0]']
#  )                              0)
#
#  block2b_activation (Activation  (None, 128, 128, 24  0          ['block2b_bn[0][0]']
#  )                              0)
#
#  block2b_se_squeeze (GlobalAver  (None, 240)         0           ['block2b_activation[0][0]']
#  agePooling2D)
#
#  block2b_se_reshape (Reshape)   (None, 1, 1, 240)    0           ['block2b_se_squeeze[0][0]']
#
#  block2b_se_reduce (Conv2D)     (None, 1, 1, 10)     2410        ['block2b_se_reshape[0][0]']
#
#  block2b_se_expand (Conv2D)     (None, 1, 1, 240)    2640        ['block2b_se_reduce[0][0]']
#
#  block2b_se_excite (Multiply)   (None, 128, 128, 24  0           ['block2b_activation[0][0]',
#                                 0)                                'block2b_se_expand[0][0]']
#
#  block2b_project_conv (Conv2D)  (None, 128, 128, 40  9600        ['block2b_se_excite[0][0]']
#                                 )
#
#  block2b_project_bn (BatchNorma  (None, 128, 128, 40  160        ['block2b_project_conv[0][0]']
#  lization)                      )
#
#  block2b_drop (FixedDropout)    (None, 128, 128, 40  0           ['block2b_project_bn[0][0]']
#                                 )
#
#  block2b_add (Add)              (None, 128, 128, 40  0           ['block2b_drop[0][0]',
#                                 )                                 'block2a_project_bn[0][0]']
#
#  block2c_expand_conv (Conv2D)   (None, 128, 128, 24  9600        ['block2b_add[0][0]']
#                                 0)
#
#  block2c_expand_bn (BatchNormal  (None, 128, 128, 24  960        ['block2c_expand_conv[0][0]']
#  ization)                       0)
#
#  block2c_expand_activation (Act  (None, 128, 128, 24  0          ['block2c_expand_bn[0][0]']
#  ivation)                       0)
#
#  block2c_dwconv (DepthwiseConv2  (None, 128, 128, 24  2160       ['block2c_expand_activation[0][0]
#  D)                             0)                               ']
#
#  block2c_bn (BatchNormalization  (None, 128, 128, 24  960        ['block2c_dwconv[0][0]']
#  )                              0)
#
#  block2c_activation (Activation  (None, 128, 128, 24  0          ['block2c_bn[0][0]']
#  )                              0)
#
#  block2c_se_squeeze (GlobalAver  (None, 240)         0           ['block2c_activation[0][0]']
#  agePooling2D)
#
#  block2c_se_reshape (Reshape)   (None, 1, 1, 240)    0           ['block2c_se_squeeze[0][0]']
#
#  block2c_se_reduce (Conv2D)     (None, 1, 1, 10)     2410        ['block2c_se_reshape[0][0]']
#
#  block2c_se_expand (Conv2D)     (None, 1, 1, 240)    2640        ['block2c_se_reduce[0][0]']
#
#  block2c_se_excite (Multiply)   (None, 128, 128, 24  0           ['block2c_activation[0][0]',
#                                 0)                                'block2c_se_expand[0][0]']
#
#  block2c_project_conv (Conv2D)  (None, 128, 128, 40  9600        ['block2c_se_excite[0][0]']
#                                 )
#
#  block2c_project_bn (BatchNorma  (None, 128, 128, 40  160        ['block2c_project_conv[0][0]']
#  lization)                      )
#
#  block2c_drop (FixedDropout)    (None, 128, 128, 40  0           ['block2c_project_bn[0][0]']
#                                 )
#
#  block2c_add (Add)              (None, 128, 128, 40  0           ['block2c_drop[0][0]',
#                                 )                                 'block2b_add[0][0]']
#
#  block2d_expand_conv (Conv2D)   (None, 128, 128, 24  9600        ['block2c_add[0][0]']
#                                 0)
#
#  block2d_expand_bn (BatchNormal  (None, 128, 128, 24  960        ['block2d_expand_conv[0][0]']
#  ization)                       0)
#
#  block2d_expand_activation (Act  (None, 128, 128, 24  0          ['block2d_expand_bn[0][0]']
#  ivation)                       0)
#
#  block2d_dwconv (DepthwiseConv2  (None, 128, 128, 24  2160       ['block2d_expand_activation[0][0]
#  D)                             0)                               ']
#
#  block2d_bn (BatchNormalization  (None, 128, 128, 24  960        ['block2d_dwconv[0][0]']
#  )                              0)
#
#  block2d_activation (Activation  (None, 128, 128, 24  0          ['block2d_bn[0][0]']
#  )                              0)
#
#  block2d_se_squeeze (GlobalAver  (None, 240)         0           ['block2d_activation[0][0]']
#  agePooling2D)
#
#  block2d_se_reshape (Reshape)   (None, 1, 1, 240)    0           ['block2d_se_squeeze[0][0]']
#
#  block2d_se_reduce (Conv2D)     (None, 1, 1, 10)     2410        ['block2d_se_reshape[0][0]']
#
#  block2d_se_expand (Conv2D)     (None, 1, 1, 240)    2640        ['block2d_se_reduce[0][0]']
#
#  block2d_se_excite (Multiply)   (None, 128, 128, 24  0           ['block2d_activation[0][0]',
#                                 0)                                'block2d_se_expand[0][0]']
#
#  block2d_project_conv (Conv2D)  (None, 128, 128, 40  9600        ['block2d_se_excite[0][0]']
#                                 )
#
#  block2d_project_bn (BatchNorma  (None, 128, 128, 40  160        ['block2d_project_conv[0][0]']
#  lization)                      )
#
#  block2d_drop (FixedDropout)    (None, 128, 128, 40  0           ['block2d_project_bn[0][0]']
#                                 )
#
#  block2d_add (Add)              (None, 128, 128, 40  0           ['block2d_drop[0][0]',
#                                 )                                 'block2c_add[0][0]']
#
#  block2e_expand_conv (Conv2D)   (None, 128, 128, 24  9600        ['block2d_add[0][0]']
#                                 0)
#
#  block2e_expand_bn (BatchNormal  (None, 128, 128, 24  960        ['block2e_expand_conv[0][0]']
#  ization)                       0)
#
#  block2e_expand_activation (Act  (None, 128, 128, 24  0          ['block2e_expand_bn[0][0]']
#  ivation)                       0)
#
#  block2e_dwconv (DepthwiseConv2  (None, 128, 128, 24  2160       ['block2e_expand_activation[0][0]
#  D)                             0)                               ']
#
#  block2e_bn (BatchNormalization  (None, 128, 128, 24  960        ['block2e_dwconv[0][0]']
#  )                              0)
#
#  block2e_activation (Activation  (None, 128, 128, 24  0          ['block2e_bn[0][0]']
#  )                              0)
#
#  block2e_se_squeeze (GlobalAver  (None, 240)         0           ['block2e_activation[0][0]']
#  agePooling2D)
#
#  block2e_se_reshape (Reshape)   (None, 1, 1, 240)    0           ['block2e_se_squeeze[0][0]']
#
#  block2e_se_reduce (Conv2D)     (None, 1, 1, 10)     2410        ['block2e_se_reshape[0][0]']
#
#  block2e_se_expand (Conv2D)     (None, 1, 1, 240)    2640        ['block2e_se_reduce[0][0]']
#
#  block2e_se_excite (Multiply)   (None, 128, 128, 24  0           ['block2e_activation[0][0]',
#                                 0)                                'block2e_se_expand[0][0]']
#
#  block2e_project_conv (Conv2D)  (None, 128, 128, 40  9600        ['block2e_se_excite[0][0]']
#                                 )
#
#  block2e_project_bn (BatchNorma  (None, 128, 128, 40  160        ['block2e_project_conv[0][0]']
#  lization)                      )
#
#  block2e_drop (FixedDropout)    (None, 128, 128, 40  0           ['block2e_project_bn[0][0]']
#                                 )
#
#  block2e_add (Add)              (None, 128, 128, 40  0           ['block2e_drop[0][0]',
#                                 )                                 'block2d_add[0][0]']
#
#  block2f_expand_conv (Conv2D)   (None, 128, 128, 24  9600        ['block2e_add[0][0]']
#                                 0)
#
#  block2f_expand_bn (BatchNormal  (None, 128, 128, 24  960        ['block2f_expand_conv[0][0]']
#  ization)                       0)
#
#  block2f_expand_activation (Act  (None, 128, 128, 24  0          ['block2f_expand_bn[0][0]']
#  ivation)                       0)
#
#  block2f_dwconv (DepthwiseConv2  (None, 128, 128, 24  2160       ['block2f_expand_activation[0][0]
#  D)                             0)                               ']
#
#  block2f_bn (BatchNormalization  (None, 128, 128, 24  960        ['block2f_dwconv[0][0]']
#  )                              0)
#
#  block2f_activation (Activation  (None, 128, 128, 24  0          ['block2f_bn[0][0]']
#  )                              0)
#
#  block2f_se_squeeze (GlobalAver  (None, 240)         0           ['block2f_activation[0][0]']
#  agePooling2D)
#
#  block2f_se_reshape (Reshape)   (None, 1, 1, 240)    0           ['block2f_se_squeeze[0][0]']
#
#  block2f_se_reduce (Conv2D)     (None, 1, 1, 10)     2410        ['block2f_se_reshape[0][0]']
#
#  block2f_se_expand (Conv2D)     (None, 1, 1, 240)    2640        ['block2f_se_reduce[0][0]']
#
#  block2f_se_excite (Multiply)   (None, 128, 128, 24  0           ['block2f_activation[0][0]',
#                                 0)                                'block2f_se_expand[0][0]']
#
#  block2f_project_conv (Conv2D)  (None, 128, 128, 40  9600        ['block2f_se_excite[0][0]']
#                                 )
#
#  block2f_project_bn (BatchNorma  (None, 128, 128, 40  160        ['block2f_project_conv[0][0]']
#  lization)                      )
#
#  block2f_drop (FixedDropout)    (None, 128, 128, 40  0           ['block2f_project_bn[0][0]']
#                                 )
#
#  block2f_add (Add)              (None, 128, 128, 40  0           ['block2f_drop[0][0]',
#                                 )                                 'block2e_add[0][0]']
#
#  block3a_expand_conv (Conv2D)   (None, 128, 128, 24  9600        ['block2f_add[0][0]']
#                                 0)
#
#  block3a_expand_bn (BatchNormal  (None, 128, 128, 24  960        ['block3a_expand_conv[0][0]']
#  ization)                       0)
#
#  block3a_expand_activation (Act  (None, 128, 128, 24  0          ['block3a_expand_bn[0][0]']
#  ivation)                       0)
#
#  block3a_dwconv (DepthwiseConv2  (None, 64, 64, 240)  6000       ['block3a_expand_activation[0][0]
#  D)                                                              ']
#
#  block3a_bn (BatchNormalization  (None, 64, 64, 240)  960        ['block3a_dwconv[0][0]']
#  )
#
#  block3a_activation (Activation  (None, 64, 64, 240)  0          ['block3a_bn[0][0]']
#  )
#
#  block3a_se_squeeze (GlobalAver  (None, 240)         0           ['block3a_activation[0][0]']
#  agePooling2D)
#
#  block3a_se_reshape (Reshape)   (None, 1, 1, 240)    0           ['block3a_se_squeeze[0][0]']
#
#  block3a_se_reduce (Conv2D)     (None, 1, 1, 10)     2410        ['block3a_se_reshape[0][0]']
#
#  block3a_se_expand (Conv2D)     (None, 1, 1, 240)    2640        ['block3a_se_reduce[0][0]']
#
#  block3a_se_excite (Multiply)   (None, 64, 64, 240)  0           ['block3a_activation[0][0]',
#                                                                   'block3a_se_expand[0][0]']
#
#  block3a_project_conv (Conv2D)  (None, 64, 64, 72)   17280       ['block3a_se_excite[0][0]']
#
#  block3a_project_bn (BatchNorma  (None, 64, 64, 72)  288         ['block3a_project_conv[0][0]']
#  lization)
#
#  block3b_expand_conv (Conv2D)   (None, 64, 64, 432)  31104       ['block3a_project_bn[0][0]']
#
#  block3b_expand_bn (BatchNormal  (None, 64, 64, 432)  1728       ['block3b_expand_conv[0][0]']
#  ization)
#
#  block3b_expand_activation (Act  (None, 64, 64, 432)  0          ['block3b_expand_bn[0][0]']
#  ivation)
#
#  block3b_dwconv (DepthwiseConv2  (None, 64, 64, 432)  10800      ['block3b_expand_activation[0][0]
#  D)                                                              ']
#
#  block3b_bn (BatchNormalization  (None, 64, 64, 432)  1728       ['block3b_dwconv[0][0]']
#  )
#
#  block3b_activation (Activation  (None, 64, 64, 432)  0          ['block3b_bn[0][0]']
#  )
#
#  block3b_se_squeeze (GlobalAver  (None, 432)         0           ['block3b_activation[0][0]']
#  agePooling2D)
#
#  block3b_se_reshape (Reshape)   (None, 1, 1, 432)    0           ['block3b_se_squeeze[0][0]']
#
#  block3b_se_reduce (Conv2D)     (None, 1, 1, 18)     7794        ['block3b_se_reshape[0][0]']
#
#  block3b_se_expand (Conv2D)     (None, 1, 1, 432)    8208        ['block3b_se_reduce[0][0]']
#
#  block3b_se_excite (Multiply)   (None, 64, 64, 432)  0           ['block3b_activation[0][0]',
#                                                                   'block3b_se_expand[0][0]']
#
#  block3b_project_conv (Conv2D)  (None, 64, 64, 72)   31104       ['block3b_se_excite[0][0]']
#
#  block3b_project_bn (BatchNorma  (None, 64, 64, 72)  288         ['block3b_project_conv[0][0]']
#  lization)
#
#  block3b_drop (FixedDropout)    (None, 64, 64, 72)   0           ['block3b_project_bn[0][0]']
#
#  block3b_add (Add)              (None, 64, 64, 72)   0           ['block3b_drop[0][0]',
#                                                                   'block3a_project_bn[0][0]']
#
#  block3c_expand_conv (Conv2D)   (None, 64, 64, 432)  31104       ['block3b_add[0][0]']
#
#  block3c_expand_bn (BatchNormal  (None, 64, 64, 432)  1728       ['block3c_expand_conv[0][0]']
#  ization)
#
#  block3c_expand_activation (Act  (None, 64, 64, 432)  0          ['block3c_expand_bn[0][0]']
#  ivation)
#
#  block3c_dwconv (DepthwiseConv2  (None, 64, 64, 432)  10800      ['block3c_expand_activation[0][0]
#  D)                                                              ']
#
#  block3c_bn (BatchNormalization  (None, 64, 64, 432)  1728       ['block3c_dwconv[0][0]']
#  )
#
#  block3c_activation (Activation  (None, 64, 64, 432)  0          ['block3c_bn[0][0]']
#  )
#
#  block3c_se_squeeze (GlobalAver  (None, 432)         0           ['block3c_activation[0][0]']
#  agePooling2D)
#
#  block3c_se_reshape (Reshape)   (None, 1, 1, 432)    0           ['block3c_se_squeeze[0][0]']
#
#  block3c_se_reduce (Conv2D)     (None, 1, 1, 18)     7794        ['block3c_se_reshape[0][0]']
#
#  block3c_se_expand (Conv2D)     (None, 1, 1, 432)    8208        ['block3c_se_reduce[0][0]']
#
#  block3c_se_excite (Multiply)   (None, 64, 64, 432)  0           ['block3c_activation[0][0]',
#                                                                   'block3c_se_expand[0][0]']
#
#  block3c_project_conv (Conv2D)  (None, 64, 64, 72)   31104       ['block3c_se_excite[0][0]']
#
#  block3c_project_bn (BatchNorma  (None, 64, 64, 72)  288         ['block3c_project_conv[0][0]']
#  lization)
#
#  block3c_drop (FixedDropout)    (None, 64, 64, 72)   0           ['block3c_project_bn[0][0]']
#
#  block3c_add (Add)              (None, 64, 64, 72)   0           ['block3c_drop[0][0]',
#                                                                   'block3b_add[0][0]']
#
#  block3d_expand_conv (Conv2D)   (None, 64, 64, 432)  31104       ['block3c_add[0][0]']
#
#  block3d_expand_bn (BatchNormal  (None, 64, 64, 432)  1728       ['block3d_expand_conv[0][0]']
#  ization)
#
#  block3d_expand_activation (Act  (None, 64, 64, 432)  0          ['block3d_expand_bn[0][0]']
#  ivation)
#
#  block3d_dwconv (DepthwiseConv2  (None, 64, 64, 432)  10800      ['block3d_expand_activation[0][0]
#  D)                                                              ']
#
#  block3d_bn (BatchNormalization  (None, 64, 64, 432)  1728       ['block3d_dwconv[0][0]']
#  )
#
#  block3d_activation (Activation  (None, 64, 64, 432)  0          ['block3d_bn[0][0]']
#  )
#
# ...
#  )                              )
#
#  block6k_activation (Activation  (None, 16, 16, 2064  0          ['block6k_bn[0][0]']
#  )                              )
#
#  block6k_se_squeeze (GlobalAver  (None, 2064)        0           ['block6k_activation[0][0]']
#  agePooling2D)
#
#  block6k_se_reshape (Reshape)   (None, 1, 1, 2064)   0           ['block6k_se_squeeze[0][0]']
#
#  block6k_se_reduce (Conv2D)     (None, 1, 1, 86)     177590      ['block6k_se_reshape[0][0]']
#
#  block6k_se_expand (Conv2D)     (None, 1, 1, 2064)   179568      ['block6k_se_reduce[0][0]']
#
#  block6k_se_excite (Multiply)   (None, 16, 16, 2064  0           ['block6k_activation[0][0]',
#                                 )                                 'block6k_se_expand[0][0]']
#
#  block6k_project_conv (Conv2D)  (None, 16, 16, 344)  710016      ['block6k_se_excite[0][0]']
#
#  block6k_project_bn (BatchNorma  (None, 16, 16, 344)  1376       ['block6k_project_conv[0][0]']
#  lization)
#
#  block6k_drop (FixedDropout)    (None, 16, 16, 344)  0           ['block6k_project_bn[0][0]']
#
#  block6k_add (Add)              (None, 16, 16, 344)  0           ['block6k_drop[0][0]',
#                                                                   'block6j_add[0][0]']
#
#  block7a_expand_conv (Conv2D)   (None, 16, 16, 2064  710016      ['block6k_add[0][0]']
#                                 )
#
#  block7a_expand_bn (BatchNormal  (None, 16, 16, 2064  8256       ['block7a_expand_conv[0][0]']
#  ization)                       )
#
#  block7a_expand_activation (Act  (None, 16, 16, 2064  0          ['block7a_expand_bn[0][0]']
#  ivation)                       )
#
#  block7a_dwconv (DepthwiseConv2  (None, 16, 16, 2064  18576      ['block7a_expand_activation[0][0]
#  D)                             )                                ']
#
#  block7a_bn (BatchNormalization  (None, 16, 16, 2064  8256       ['block7a_dwconv[0][0]']
#  )                              )
#
#  block7a_activation (Activation  (None, 16, 16, 2064  0          ['block7a_bn[0][0]']
#  )                              )
#
#  block7a_se_squeeze (GlobalAver  (None, 2064)        0           ['block7a_activation[0][0]']
#  agePooling2D)
#
#  block7a_se_reshape (Reshape)   (None, 1, 1, 2064)   0           ['block7a_se_squeeze[0][0]']
#
#  block7a_se_reduce (Conv2D)     (None, 1, 1, 86)     177590      ['block7a_se_reshape[0][0]']
#
#  block7a_se_expand (Conv2D)     (None, 1, 1, 2064)   179568      ['block7a_se_reduce[0][0]']
#
#  block7a_se_excite (Multiply)   (None, 16, 16, 2064  0           ['block7a_activation[0][0]',
#                                 )                                 'block7a_se_expand[0][0]']
#
#  block7a_project_conv (Conv2D)  (None, 16, 16, 576)  1188864     ['block7a_se_excite[0][0]']
#
#  block7a_project_bn (BatchNorma  (None, 16, 16, 576)  2304       ['block7a_project_conv[0][0]']
#  lization)
#
#  block7b_expand_conv (Conv2D)   (None, 16, 16, 3456  1990656     ['block7a_project_bn[0][0]']
#                                 )
#
#  block7b_expand_bn (BatchNormal  (None, 16, 16, 3456  13824      ['block7b_expand_conv[0][0]']
#  ization)                       )
#
#  block7b_expand_activation (Act  (None, 16, 16, 3456  0          ['block7b_expand_bn[0][0]']
#  ivation)                       )
#
#  block7b_dwconv (DepthwiseConv2  (None, 16, 16, 3456  31104      ['block7b_expand_activation[0][0]
#  D)                             )                                ']
#
#  block7b_bn (BatchNormalization  (None, 16, 16, 3456  13824      ['block7b_dwconv[0][0]']
#  )                              )
#
#  block7b_activation (Activation  (None, 16, 16, 3456  0          ['block7b_bn[0][0]']
#  )                              )
#
#  block7b_se_squeeze (GlobalAver  (None, 3456)        0           ['block7b_activation[0][0]']
#  agePooling2D)
#
#  block7b_se_reshape (Reshape)   (None, 1, 1, 3456)   0           ['block7b_se_squeeze[0][0]']
#
#  block7b_se_reduce (Conv2D)     (None, 1, 1, 144)    497808      ['block7b_se_reshape[0][0]']
#
#  block7b_se_expand (Conv2D)     (None, 1, 1, 3456)   501120      ['block7b_se_reduce[0][0]']
#
#  block7b_se_excite (Multiply)   (None, 16, 16, 3456  0           ['block7b_activation[0][0]',
#                                 )                                 'block7b_se_expand[0][0]']
#
#  block7b_project_conv (Conv2D)  (None, 16, 16, 576)  1990656     ['block7b_se_excite[0][0]']
#
#  block7b_project_bn (BatchNorma  (None, 16, 16, 576)  2304       ['block7b_project_conv[0][0]']
#  lization)
#
#  block7b_drop (FixedDropout)    (None, 16, 16, 576)  0           ['block7b_project_bn[0][0]']
#
#  block7b_add (Add)              (None, 16, 16, 576)  0           ['block7b_drop[0][0]',
#                                                                   'block7a_project_bn[0][0]']
#
#  block7c_expand_conv (Conv2D)   (None, 16, 16, 3456  1990656     ['block7b_add[0][0]']
#                                 )
#
#  block7c_expand_bn (BatchNormal  (None, 16, 16, 3456  13824      ['block7c_expand_conv[0][0]']
#  ization)                       )
#
#  block7c_expand_activation (Act  (None, 16, 16, 3456  0          ['block7c_expand_bn[0][0]']
#  ivation)                       )
#
#  block7c_dwconv (DepthwiseConv2  (None, 16, 16, 3456  31104      ['block7c_expand_activation[0][0]
#  D)                             )                                ']
#
#  block7c_bn (BatchNormalization  (None, 16, 16, 3456  13824      ['block7c_dwconv[0][0]']
#  )                              )
#
#  block7c_activation (Activation  (None, 16, 16, 3456  0          ['block7c_bn[0][0]']
#  )                              )
#
#  block7c_se_squeeze (GlobalAver  (None, 3456)        0           ['block7c_activation[0][0]']
#  agePooling2D)
#
#  block7c_se_reshape (Reshape)   (None, 1, 1, 3456)   0           ['block7c_se_squeeze[0][0]']
#
#  block7c_se_reduce (Conv2D)     (None, 1, 1, 144)    497808      ['block7c_se_reshape[0][0]']
#
#  block7c_se_expand (Conv2D)     (None, 1, 1, 3456)   501120      ['block7c_se_reduce[0][0]']
#
#  block7c_se_excite (Multiply)   (None, 16, 16, 3456  0           ['block7c_activation[0][0]',
#                                 )                                 'block7c_se_expand[0][0]']
#
#  block7c_project_conv (Conv2D)  (None, 16, 16, 576)  1990656     ['block7c_se_excite[0][0]']
#
#  block7c_project_bn (BatchNorma  (None, 16, 16, 576)  2304       ['block7c_project_conv[0][0]']
#  lization)
#
#  block7c_drop (FixedDropout)    (None, 16, 16, 576)  0           ['block7c_project_bn[0][0]']
#
#  block7c_add (Add)              (None, 16, 16, 576)  0           ['block7c_drop[0][0]',
#                                                                   'block7b_add[0][0]']
#
#  top_conv (Conv2D)              (None, 16, 16, 2304  1327104     ['block7c_add[0][0]']
#                                 )
#
#  top_bn (BatchNormalization)    (None, 16, 16, 2304  9216        ['top_conv[0][0]']
#                                 )
#
#  top_activation (Activation)    (None, 16, 16, 2304  0           ['top_bn[0][0]']
#                                 )
#
#  avg_pool (GlobalAveragePooling  (None, 2304)        0           ['top_activation[0][0]']
#  2D)
#
#  dropout_2 (Dropout)            (None, 2304)         0           ['avg_pool[0][0]']
#
#  dense_2 (Dense)                (None, 7)            16135       ['dropout_2[0][0]']
#
# ==================================================================================================
# Total params: 40,976,271
# Trainable params: 13,685,197
# Non-trainable params: 27,291,074
# __________________________________________________________________________________________________

# %%
opt = tf.keras.optimizers.Adam(lr = 1e-5)
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
cb = ModelCheckpoint('EfnB6_multi_label_model_combine.h5', monitor='val_loss', mode='min', verbose=1, save_best_only=True)
reduceLROnPlat = ReduceLROnPlateau(monitor='val_loss', factor = 0.5, patience = 10, 
                                   verbose=1, mode='auto', min_delta = 0.0001, cooldown=0, min_lr=1e-5)
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=5)
model.compile(optimizer=opt, loss="binary_crossentropy", metrics=['accuracy'])

# %%
training = model.fit_generator(generator=train_generator
                                ,epochs=EPOCHS,
                                steps_per_epoch=train_generator.samples//BATCH_SIZE
                                ,callbacks=[reduceLROnPlat, es])
# Out:
# <ipython-input-64-e28d103acac3>:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   training = model.fit_generator(generator=train_generator
# Epoch 1/20
# 1343/1343 [==============================] - ETA: 0s - loss: 0.1351 - accuracy: 0.7111WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 1343/1343 [==============================] - 601s 447ms/step - loss: 0.1351 - accuracy: 0.7111 - lr: 1.0000e-05
# Epoch 2/20
# 1343/1343 [==============================] - ETA: 0s - loss: 0.1265 - accuracy: 0.7093WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 1343/1343 [==============================] - 593s 441ms/step - loss: 0.1265 - accuracy: 0.7093 - lr: 1.0000e-05
# Epoch 3/20
# 1343/1343 [==============================] - ETA: 0s - loss: 0.1208 - accuracy: 0.6999WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 1343/1343 [==============================] - 593s 442ms/step - loss: 0.1208 - accuracy: 0.6999 - lr: 1.0000e-05
# Epoch 4/20
# 1343/1343 [==============================] - ETA: 0s - loss: 0.1167 - accuracy: 0.7111WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 1343/1343 [==============================] - 602s 448ms/step - loss: 0.1167 - accuracy: 0.7111 - lr: 1.0000e-05
# Epoch 5/20
# 1343/1343 [==============================] - ETA: 0s - loss: 0.1118 - accuracy: 0.7111WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 1343/1343 [==============================] - 593s 441ms/step - loss: 0.1118 - accuracy: 0.7111 - lr: 1.0000e-05
# Epoch 6/20
# 1343/1343 [==============================] - ETA: 0s - loss: 0.1094 - accuracy: 0.7118WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 1343/1343 [==============================] - 592s 441ms/step - loss: 0.1094 - accuracy: 0.7118 - lr: 1.0000e-05
# Epoch 7/20
# 1343/1343 [==============================] - ETA: 0s - loss: 0.1079 - accuracy: 0.7135WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 1343/1343 [==============================] - 593s 441ms/step - loss: 0.1079 - accuracy: 0.7135 - lr: 1.0000e-05
# Epoch 8/20
# 1343/1343 [==============================] - ETA: 0s - loss: 0.1043 - accuracy: 0.7246WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 1343/1343 [==============================] - 597s 445ms/step - loss: 0.1043 - accuracy: 0.7246 - lr: 1.0000e-05
# Epoch 9/20
# 1343/1343 [==============================] - ETA: 0s - loss: 0.1041 - accuracy: 0.7257WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 1343/1343 [==============================] - 594s 442ms/step - loss: 0.1041 - accuracy: 0.7257 - lr: 1.0000e-05
# Epoch 10/20
# 1343/1343 [==============================] - ETA: 0s - loss: 0.1026 - accuracy: 0.7194WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 1343/1343 [==============================] - 591s 440ms/step - loss: 0.1026 - accuracy: 0.7194 - lr: 1.0000e-05
# Epoch 11/20
# 1343/1343 [==============================] - ETA: 0s - loss: 0.0997 - accuracy: 0.7227WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 1343/1343 [==============================] - 608s 452ms/step - loss: 0.0997 - accuracy: 0.7227 - lr: 1.0000e-05
# Epoch 12/20
# 1343/1343 [==============================] - ETA: 0s - loss: 0.0979 - accuracy: 0.7351WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 1343/1343 [==============================] - 622s 463ms/step - loss: 0.0979 - accuracy: 0.7351 - lr: 1.0000e-05
# Epoch 13/20
# 1343/1343 [==============================] - ETA: 0s - loss: 0.0983 - accuracy: 0.7291WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 1343/1343 [==============================] - 610s 454ms/step - loss: 0.0983 - accuracy: 0.7291 - lr: 1.0000e-05
# Epoch 14/20
# 1343/1343 [==============================] - ETA: 0s - loss: 0.0968 - accuracy: 0.7240WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 1343/1343 [==============================] - 598s 445ms/step - loss: 0.0968 - accuracy: 0.7240 - lr: 1.0000e-05
# Epoch 15/20
# 1343/1343 [==============================] - ETA: 0s - loss: 0.0951 - accuracy: 0.7316WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 1343/1343 [==============================] - 598s 445ms/step - loss: 0.0951 - accuracy: 0.7316 - lr: 1.0000e-05
# Epoch 16/20
# 1343/1343 [==============================] - ETA: 0s - loss: 0.0941 - accuracy: 0.7316WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 1343/1343 [==============================] - 603s 449ms/step - loss: 0.0941 - accuracy: 0.7316 - lr: 1.0000e-05
# Epoch 17/20
# 1343/1343 [==============================] - ETA: 0s - loss: 0.0919 - accuracy: 0.7342WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 1343/1343 [==============================] - 600s 446ms/step - loss: 0.0919 - accuracy: 0.7342 - lr: 1.0000e-05
# Epoch 18/20
# 1343/1343 [==============================] - ETA: 0s - loss: 0.0914 - accuracy: 0.7403WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 1343/1343 [==============================] - 598s 445ms/step - loss: 0.0914 - accuracy: 0.7403 - lr: 1.0000e-05
# Epoch 19/20
# 1343/1343 [==============================] - ETA: 0s - loss: 0.0910 - accuracy: 0.7383WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 1343/1343 [==============================] - 597s 445ms/step - loss: 0.0910 - accuracy: 0.7383 - lr: 1.0000e-05
# Epoch 20/20
# 1343/1343 [==============================] - ETA: 0s - loss: 0.0895 - accuracy: 0.7377WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 1343/1343 [==============================] - 605s 450ms/step - loss: 0.0895 - accuracy: 0.7377 - lr: 1.0000e-05

# %%
model.save("EfnB6_multi_label_model_combine_2.h5")
# Out:
# C:\Users\KARTIK\anaconda3\lib\site-packages\keras\engine\functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)

# %%
import pickle
pkl_filename = "first_try.pkl"
filename = 'finalized_model.sav'
pickle.dump(model, open(filename, 'wb'))
# Out:
# INFO:tensorflow:Assets written to: ram://93c02239-3281-4bc0-8250-879138278000/assets
# C:\Users\KARTIK\anaconda3\lib\site-packages\keras\engine\functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# C:\Users\KARTIK\anaconda3\lib\site-packages\keras\saving\saved_model\layer_serialization.py:112: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   return generic_utils.serialize_keras_object(obj)
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# <ipython-input-70-1cd17cfe4fc0> in <module>
#       2 pkl_filename = "first_try.pkl"
#       3 filename = 'finalized_model.sav'
# ----> 4 pickle.dump(model, open(filename, 'wb'))
#
# ~\anaconda3\lib\site-packages\keras\engine\training.py in __reduce__(self)
#     313     if self.built:
#     314       return (pickle_utils.deserialize_model_from_bytecode,
# --> 315               pickle_utils.serialize_model_as_bytecode(self))
#     316     else:
#     317       # SavedModel (and hence serialize_model_as_bytecode) only support
#
# ~\anaconda3\lib\site-packages\keras\saving\pickle_utils.py in serialize_model_as_bytecode(model)
#      75         with tf.io.gfile.GFile(dest_path, "rb") as f:
#      76           info = tarfile.TarInfo(name=os.path.relpath(dest_path, temp_dir))
# ---> 77           info.size = f.size()
#      78           archive.addfile(tarinfo=info, fileobj=f)
#      79   tf.io.gfile.rmtree(temp_dir)
#
# ~\anaconda3\lib\site-packages\tensorflow\python\lib\io\file_io.py in size(self)
#      97   def size(self):
#      98     """Returns the size of the file."""
# ---> 99     return stat(self.__name).length
#     100
#     101   def write(self, file_content):
#
# ~\anaconda3\lib\site-packages\tensorflow\python\lib\io\file_io.py in stat(filename)
#     908     errors.OpError: If the operation fails.
#     909   """
# --> 910   return stat_v2(filename)
#     911
#     912
#
# ~\anaconda3\lib\site-packages\tensorflow\python\lib\io\file_io.py in stat_v2(path)
#     924     errors.OpError: If the operation fails.
#     925   """
# --> 926   return _pywrap_file_io.Stat(compat.path_to_str(path))
#     927
#     928
#
# NotFoundError:

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 041D-30FD
#
#  Directory of C:\Users\KARTIK\Downloads\Soft. Eng. Prject\AI4VN-Hackathon2020-main\AI4VN-Hackathon2020-main\AI4VN
#
# 07-12-2021  08:14    <DIR>          .
# 06-12-2021  12:27    <DIR>          ..
# 06-12-2021  12:27    <DIR>          .ipynb_checkpoints
# 06-12-2021  12:27    <DIR>          csv_file
# 07-12-2021  01:56       275,231,960 EfnB6_multi_label_model_combine_2.h5
# 07-12-2021  08:14                 0 first_try.pkl
# 06-12-2021  12:27    <DIR>          fold
# 06-12-2021  12:36    <DIR>          models
# 06-12-2021  12:27    <DIR>          predict
# 06-12-2021  12:27    <DIR>          submission
# 06-12-2021  12:27    <DIR>          tools
# 06-12-2021  21:40    <DIR>          train
# 07-12-2021  08:15    <DIR>          training
#                2 File(s)    275,231,960 bytes
#               11 Dir(s)  424,344,711,168 bytes free
